# %%
from generators.gen_balanced_tree import generate as gen_balanced_tree
from generators.gen_random_tree import generate as gen_random_tree
from draw import draw_tree

# %%
gen_balanced_tree(seed=2026)

# %% [markdown]
# # Breadth-First Search

# %%
def BFS(tree, target: int, source: int = 0):
    
        # Mark all the vertices as not visited
        visited = [False] * (max(tree) + 1)

        # Create a queue for BFS
        queue = []

        # FIXME: Mark the source node as
        # visited and enqueue it

        while queue:
            # Dequeue a vertex from
            # queue and print it
            node = queue.pop(0)
            
            # FIXME: Check if the node is the target

            # FIXME: Get all adjacent vertices of the
            # dequeued vertex s.
            # If an adjacent has not been visited,
            # then mark it visited and enqueue it

# %% [markdown]
# ## Testing our code out

# %%
tree = gen_balanced_tree(seed=2026)
draw_tree(tree, title="Balanced Tree")
BFS(tree, target=12)

# %% [markdown]
# # Depth-First Search

# %%
def DFS(tree, target: int, source: int = 0):    
    visited = [False] * (max(tree) + 1)

    # Use our stack to track which nodes to visit next
    stack = []

    # FIXME: Mark the source node as 
    # visited and push it to the stack

    while stack:
        node = stack.pop()
        # FIXME: Check if the node is the target

        # FIXME: Get all adjacent vertices of the
        # popped vertex s.
        # If an adjacent has not been visited,
        # then mark it visited and push it to the stack

# %%
tree = gen_balanced_tree(seed=2026)
draw_tree(tree, title="Balanced Tree")
DFS(tree, target=12)
